# %% [markdown]
# <a href="https://colab.research.google.com/github/sagarkakkar03/FastAPIPractice/blob/main/Serialization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle
import joblib
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %% [markdown]
# ## Read the Data

# %%
df = pd.read_csv('sample_data/california_housing_train.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
df.dropna()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
X = df.drop('median_house_value', axis=1)
y = df['median_house_value']

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
y_pred
# Out:
# array([  7128.08452517,  73675.60144224, -31317.28531191, ...,
#        100878.32872671,  63733.22144717, 186850.92450275])

# %%
r2_score(y, y_pred)
# Out:
# 0.6413378529502687

# %% [markdown]
# ## Pickle

# %%
with open('model.pkl', 'wb') as f:
  pickle.dump(model, f)

# %%
with open('model.pkl', 'rb') as f:
  pickle_model = pickle.load(f)

# %%
pickle_model
# Out:
# LinearRegression()

# %%
y_pred_pickle = pickle_model.predict(X)

# %%
r2_score(y, y_pred_pickle)
# Out:
# 0.6413378529502687

# %% [markdown]
# ## Joblib

# %%
joblib.dump(model, 'model.joblib')
# Out:
# ['model.joblib']

# %%
model_joblib = joblib.load('model.joblib')

# %%
y_pred_joblib = model_joblib.predict(X)

# %%
r2_score(y, y_pred_joblib)
# Out:
# 0.6413378529502687
